# %% [markdown]
# <a href="https://colab.research.google.com/github/Deokgu/python/blob/main/%EB%B0%9C%EC%A0%84%EC%9B%90%EB%B3%84_%EB%B0%9C%EC%A0%84%EB%9F%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 2s (5,192 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
# 한글 처리 1
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc('font', family = 'NanumGothic')
mpl.rcParams['axes.unicode_minus'] = False

# %%
# 한글 처리 2
from matplotlib import font_manager, rc
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font)

# %%
import requests
import json
import pandas as pd
from pandas import json_normalize

url = 'http://apis.data.go.kr/B552115/PvAmountByPwrGen/getPvAmountByPwrGen'
para1 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '1', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }
para2 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '2', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }
para3 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '3', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }
para4 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '4', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }
para5 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '5', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }
para6 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '6', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }
para7 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '7', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }
para8 ={'serviceKey' : 'iLOsKtVF6MDKTtRhUGMopE5wYO+cCQNff/qwR+EXqEc3tFn6JRqqKB0eN2WuPsqWHtjeiiUaq3kyvx9ajhH8lg==', 'pageNo' : '8', 'numOfRows' : '24', 'dataType' : 'json', 'tradeYmd' : '20220904' }

res1 = requests.get(url, params=para1)
print(res1.content); print("")
res2 = requests.get(url, params=para2)
print(res2.content); print("")
res3 = requests.get(url, params=para3)
print(res3.content); print("")
res4 = requests.get(url, params=para4)
print(res4.content); print("")
res5 = requests.get(url, params=para5)
print(res5.content); print("")
res6 = requests.get(url, params=para6)
print(res6.content); print("")
res7 = requests.get(url, params=para7)
print(res7.content); print("")
res8 = requests.get(url, params=para8)
print(res8.content); print("")

json_file1 = json.loads(res1.text)
json_file2 = json.loads(res2.text)
json_file3 = json.loads(res3.text)
json_file4 = json.loads(res4.text)
json_file5 = json.loads(res5.text)
json_file6 = json.loads(res6.text)
json_file7 = json.loads(res7.text)
json_file8 = json.loads(res8.text)

df1 = json_normalize(json_file1['response']['body']['items']['item'])
df2 = json_normalize(json_file2['response']['body']['items']['item'])
df3 = json_normalize(json_file3['response']['body']['items']['item'])
df4 = json_normalize(json_file4['response']['body']['items']['item'])
df5 = json_normalize(json_file5['response']['body']['items']['item'])
df6 = json_normalize(json_file6['response']['body']['items']['item'])
df7 = json_normalize(json_file7['response']['body']['items']['item'])
df8 = json_normalize(json_file8['response']['body']['items']['item'])

df1.to_excel("유전.xlsx"); df1.to_csv("유전.csv")
df2.to_excel("유연탄.xlsx"); df2.to_csv("유연탄.csv")
df3.to_excel("원자력.xlsx"); df3.to_csv("원자력.csv")
df4.to_excel("양수.xlsx"); df4.to_csv("양수.csv")
df5.to_excel("신재생·기타.xlsx"); df5.to_csv("신재생·기타.csv")
df6.to_excel("수력.xlsx"); df6.to_csv("수력.csv")
df7.to_excel("무연탄.xlsx"); df7.to_csv("무연탄.csv")
df8.to_excel("천연가스.xlsx"); df8.to_csv("천연가스.csv")
# Out:
# b'{  "response" : {    "header" : {      "resultCode" : "00",      "resultMsg" : "OK"    },    "body" : {      "dataType" : "JSON",      "totalCount" : "192",      "numOfRows" : "24",      "pageNo" : "1",      "items" : {        "item" : [ {          "tradeNo" : "01",          "fuelTpCd" : "\xec\x9c\xa0\xec\xa0\x84",          "tradeYmd" : "20220904",          "amgo" : 236.256,          "rn" : 1        }, {          "tradeNo" : "02",          "fuelTpCd" : "\xec\x9c\xa0\xec\xa0\x84",          "tradeYmd" : "20220904",          "amgo" : 236.385,          "rn" : 2        }, {          "tradeNo" : "03",          "fuelTpCd" : "\xec\x9c\xa0\xec\xa0\x84",          "tradeYmd" : "20220904",          "amgo" : 235.611,          "rn" : 3        }, {          "tradeNo" : "04",          "fuelTpCd" : "\xec\x9c\xa0\xec\xa0\x84",          "tradeYmd" : "20220904",          "amgo" : 235.715,          "rn" : 4        }, {          "tradeNo" : "05",          "fuelTpCd" : "\xec\x9c\xa0\xec\xa0\x84",        
# ...

# %%
df1
# Out:
#    tradeNo fuelTpCd  tradeYmd     amgo  rn
# 0       01       유전  20220904  236.256   1
# 1       02       유전  20220904  236.385   2
# 2       03       유전  20220904  235.611   3
# 3       04       유전  20220904  235.715   4
# 4       05       유전  20220904  235.895   5
# 5       06       유전  20220904  236.326   6
# 6       07       유전  20220904  236.475   7
# 7       08       유전  20220904  235.698   8
# 8       09       유전  20220904  235.985   9
# 9       10       유전  20220904  236.146  10
# 10      11       유전  20220904  236.022  11
# 11      12       유전  20220904  236.742  12
# 12      13       유전  20220904  236.245  13
# 13      14       유전  20220904  235.876  14
# 14      15       유전  20220904  236.673  15
# 15      16       유전  20220904  235.126  16
# 16      17       유전  20220904  235.581  17
# 17      18       유전  20220904  235.726  18
# 18      19       유전  20220904  236.775  19
# 19      20       유전  20220904   55.778  20
# 20      21       유전  20220904   15.084  21
# ...

# %%
df2
# Out:
#    tradeNo fuelTpCd  tradeYmd       amgo  rn
# 0       01      유연탄  20220904  18085.474  25
# 1       02      유연탄  20220904  17290.765  26
# 2       03      유연탄  20220904  16581.130  27
# 3       04      유연탄  20220904  16236.126  28
# 4       05      유연탄  20220904  16145.542  29
# 5       06      유연탄  20220904  16236.841  30
# 6       07      유연탄  20220904  16375.270  31
# 7       08      유연탄  20220904  16359.549  32
# 8       09      유연탄  20220904  16343.951  33
# 9       10      유연탄  20220904  16368.938  34
# 10      11      유연탄  20220904  16785.375  35
# 11      12      유연탄  20220904  16991.970  36
# 12      13      유연탄  20220904  17119.523  37
# 13      14      유연탄  20220904  17471.403  38
# 14      15      유연탄  20220904  18081.115  39
# 15      16      유연탄  20220904  18422.125  40
# 16      17      유연탄  20220904  18834.341  41
# 17      18      유연탄  20220904  19919.308  42
# 18      19      유연탄  20220904  21142.545  43
# 19      20      유연탄  20220904  21464.193  44
# ...

# %%
df3
# Out:
#    tradeNo fuelTpCd  tradeYmd       amgo  rn
# 0       01      원자력  20220904  20186.265  49
# 1       02      원자력  20220904  20184.402  50
# 2       03      원자력  20220904  20189.023  51
# 3       04      원자력  20220904  20191.563  52
# 4       05      원자력  20220904  20191.112  53
# 5       06      원자력  20220904  20192.368  54
# 6       07      원자력  20220904  20192.259  55
# 7       08      원자력  20220904  20189.942  56
# 8       09      원자력  20220904  20186.748  57
# 9       10      원자력  20220904  20185.708  58
# 10      11      원자력  20220904  20191.842  59
# 11      12      원자력  20220904  20191.518  60
# 12      13      원자력  20220904  20185.047  61
# 13      14      원자력  20220904  20180.936  62
# 14      15      원자력  20220904  20179.371  63
# 15      16      원자력  20220904  20176.867  64
# 16      17      원자력  20220904  20175.515  65
# 17      18      원자력  20220904  20174.641  66
# 18      19      원자력  20220904  20177.976  67
# 19      20      원자력  20220904  20183.159  68
# ...

# %%
df4
# Out:
#    tradeNo fuelTpCd  tradeYmd     amgo  rn
# 0       01       양수  20220904   62.498  73
# 1       02       양수  20220904    0.000  74
# 2       03       양수  20220904    0.000  75
# 3       04       양수  20220904    0.000  76
# 4       05       양수  20220904    0.091  77
# 5       06       양수  20220904    0.000  78
# 6       07       양수  20220904    0.000  79
# 7       08       양수  20220904    0.000  80
# 8       09       양수  20220904    0.001  81
# 9       10       양수  20220904    0.000  82
# 10      11       양수  20220904    0.000  83
# 11      12       양수  20220904    0.198  84
# 12      13       양수  20220904    0.041  85
# 13      14       양수  20220904  171.583  86
# 14      15       양수  20220904  503.522  87
# 15      16       양수  20220904  775.955  88
# 16      17       양수  20220904  790.127  89
# 17      18       양수  20220904  786.316  90
# 18      19       양수  20220904  725.980  91
# 19      20       양수  20220904  448.440  92
# 20      21       양수  20220904  200.002  93
# ...

# %%
df5
# Out:
#    tradeNo fuelTpCd  tradeYmd      amgo   rn
# 0       01   신재생·기타  20220904  2439.013   97
# 1       02   신재생·기타  20220904  2412.726   98
# 2       03   신재생·기타  20220904  2511.929   99
# 3       04   신재생·기타  20220904  2475.706  100
# 4       05   신재생·기타  20220904  2466.134  101
# 5       06   신재생·기타  20220904  2460.791  102
# 6       07   신재생·기타  20220904  2468.434  103
# 7       08   신재생·기타  20220904  2754.430  104
# 8       09   신재생·기타  20220904  3323.307  105
# 9       10   신재생·기타  20220904  3931.992  106
# 10      11   신재생·기타  20220904  3900.625  107
# 11      12   신재생·기타  20220904  4017.612  108
# 12      13   신재생·기타  20220904  3929.233  109
# 13      14   신재생·기타  20220904  3799.929  110
# 14      15   신재생·기타  20220904  3598.053  111
# 15      16   신재생·기타  20220904  3180.552  112
# 16      17   신재생·기타  20220904  2928.499  113
# 17      18   신재생·기타  20220904  3145.294  114
# 18      19   신재생·기타  20220904  3120.137  115
# 19      20   신재생·기타  20220904  2958.538  116
# ...

# %%
df6
# Out:
#    tradeNo fuelTpCd  tradeYmd      amgo   rn
# 0       01       수력  20220904  1089.041  121
# 1       02       수력  20220904  1090.259  122
# 2       03       수력  20220904  1089.647  123
# 3       04       수력  20220904  1089.411  124
# 4       05       수력  20220904  1089.055  125
# 5       06       수력  20220904  1089.352  126
# 6       07       수력  20220904  1095.727  127
# 7       08       수력  20220904  1094.106  128
# 8       09       수력  20220904  1154.790  129
# 9       10       수력  20220904  1154.702  130
# 10      11       수력  20220904  1161.424  131
# 11      12       수력  20220904  1162.748  132
# 12      13       수력  20220904  1115.056  133
# 13      14       수력  20220904  1109.353  134
# 14      15       수력  20220904  1095.069  135
# 15      16       수력  20220904  1087.733  136
# 16      17       수력  20220904  1080.791  137
# 17      18       수력  20220904  1071.392  138
# 18      19       수력  20220904  1066.098  139
# 19      20       수력  20220904  1057.175  140
# ...

# %%
df7
# Out:
#    tradeNo fuelTpCd  tradeYmd     amgo   rn
# 0       01      무연탄  20220904  323.735  145
# 1       02      무연탄  20220904  323.819  146
# 2       03      무연탄  20220904  309.960  147
# 3       04      무연탄  20220904  299.759  148
# 4       05      무연탄  20220904  293.521  149
# 5       06      무연탄  20220904  289.932  150
# 6       07      무연탄  20220904  288.861  151
# 7       08      무연탄  20220904  288.657  152
# 8       09      무연탄  20220904  289.206  153
# 9       10      무연탄  20220904  289.151  154
# 10      11      무연탄  20220904  291.255  155
# 11      12      무연탄  20220904  291.358  156
# 12      13      무연탄  20220904  289.628  157
# 13      14      무연탄  20220904  298.494  158
# 14      15      무연탄  20220904  317.361  159
# 15      16      무연탄  20220904  328.600  160
# 16      17      무연탄  20220904  317.911  161
# 17      18      무연탄  20220904  316.992  162
# 18      19      무연탄  20220904  325.029  163
# 19      20      무연탄  20220904  329.597  164
# ...

# %%
df8
# Out:
#    tradeNo fuelTpCd  tradeYmd       amgo   rn
# 0       01      LNG  20220904  11334.192  169
# 1       02      LNG  20220904  10829.319  170
# 2       03      LNG  20220904  10277.772  171
# 3       04      LNG  20220904  10221.070  172
# 4       05      LNG  20220904  10165.078  173
# 5       06      LNG  20220904  10319.906  174
# 6       07      LNG  20220904  10569.689  175
# 7       08      LNG  20220904  11059.437  176
# 8       09      LNG  20220904  12077.983  177
# 9       10      LNG  20220904  12862.587  178
# 10      11      LNG  20220904  13478.362  179
# 11      12      LNG  20220904  13335.940  180
# 12      13      LNG  20220904  13215.799  181
# 13      14      LNG  20220904  13236.421  182
# 14      15      LNG  20220904  13388.015  183
# 15      16      LNG  20220904  14346.876  184
# 16      17      LNG  20220904  15735.798  185
# 17      18      LNG  20220904  16074.169  186
# 18      19      LNG  20220904  16682.283  187
# ...

# %%
import matplotlib.pyplot as plt

df1['tradeNo'] = pd.to_numeric(df1['tradeNo'])
df1['amgo'] = pd.to_numeric(df1['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df1['tradeNo'], df1['amgo'], color = 'orange', lw = 1.5, alpha = 0.7, label='유전')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('유전 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df2['tradeNo'] = pd.to_numeric(df2['tradeNo'])
df2['amgo'] = pd.to_numeric(df2['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df2['tradeNo'], df2['amgo'], color = 'brown', lw = 1.5, alpha = 0.7, label='유연탄')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('유연탄 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df3['tradeNo'] = pd.to_numeric(df3['tradeNo'])
df3['amgo'] = pd.to_numeric(df3['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df3['tradeNo'], df3['amgo'], color = 'r', lw = 1.5, alpha = 0.7, label='원자력')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('원자력 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df4['tradeNo'] = pd.to_numeric(df4['tradeNo'])
df4['amgo'] = pd.to_numeric(df4['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df4['tradeNo'], df4['amgo'], color = 'skyblue', lw = 1.5, alpha = 0.7, label='양수')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('양수 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df5['tradeNo'] = pd.to_numeric(df5['tradeNo'])
df5['amgo'] = pd.to_numeric(df5['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df5['tradeNo'], df5['amgo'], color = 'yellowgreen', lw = 1.5, alpha = 0.7, label='신재생·기타')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('신재생·기타	 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df6['tradeNo'] = pd.to_numeric(df6['tradeNo'])
df6['amgo'] = pd.to_numeric(df6['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df6['tradeNo'], df6['amgo'], color = 'blue', lw = 1.5, alpha = 0.7, label='수력')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('수력 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df7['tradeNo'] = pd.to_numeric(df7['tradeNo'])
df7['amgo'] = pd.to_numeric(df7['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df7['tradeNo'], df7['amgo'], color = 'black', lw = 1.5, alpha = 0.7, label='무연탄')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('무연탄 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df8['tradeNo'] = pd.to_numeric(df8['tradeNo'])
df8['amgo'] = pd.to_numeric(df8['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df8['tradeNo'], df8['amgo'], color = 'gray', lw = 1.5, alpha = 0.7, label='천연가스')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('천연가스 발전량', fontweight='bold', fontsize = 12)
ax.legend()

# %%
import matplotlib.pyplot as plt

df1['tradeNo'] = pd.to_numeric(df8['tradeNo'])
df1['amgo'] = pd.to_numeric(df8['amgo'], downcast='float')

fig = plt.figure(figsize=(14,6))
ax = plt.subplot(1,1,1)

ax.plot(df1['tradeNo'], df1['amgo'], color = 'orange', lw = 1.5, alpha = 0.7, label='유전')
ax.plot(df2['tradeNo'], df2['amgo'], color = 'brown', lw = 1.5, alpha = 0.7, label='유연탄')
ax.plot(df3['tradeNo'], df3['amgo'], color = 'r', lw = 1.5, alpha = 0.7, label='원자력')
ax.plot(df4['tradeNo'], df4['amgo'], color = 'skyblue', lw = 1.5, alpha = 0.7, label='양수')
ax.plot(df5['tradeNo'], df5['amgo'], color = 'yellowgreen', lw = 1.5, alpha = 0.7, label='신재생·기타')
ax.plot(df6['tradeNo'], df6['amgo'], color = 'blue', lw = 1.5, alpha = 0.7, label='수력')
ax.plot(df7['tradeNo'], df7['amgo'], color = 'black', lw = 1.5, alpha = 0.7, label='무연탄')
ax.plot(df8['tradeNo'], df8['amgo'], color = 'gray', lw = 1.5, alpha = 0.7, label='천연가스')

ax.set_xlabel('시간', fontweight='bold', fontsize = 12)
ax.set_ylabel('발전량', fontweight='bold', fontsize = 12)
ax.set_title('발전원별 발전량', fontweight='bold', fontsize = 12)
ax.legend()
